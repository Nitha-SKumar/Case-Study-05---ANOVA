# %% [markdown]
# ### XYZ Company has offices in four different zones. The company wishes to investigate the following
# - The mean sales generated by each zone.
# - Total sales generated by all the zones for each month.
# - Check whether all the zones generate the same amount of sales.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Loadinng the Dataset

# %%
salesData = pd.read_csv('Sales_data_zone_wise.csv')
salesData
# Out:
#          Month  Zone - A  Zone - B  Zone - C  Zone - D
# 0    Month - 1   1483525   1748451   1523308   2267260
# 1    Month - 2   1238428   1707421   2212113   1994341
# 2    Month - 3   1860771   2091194   1282374   1241600
# 3    Month - 4   1871571   1759617   2290580   2252681
# 4    Month - 5   1244922   1606010   1818334   1326062
# 5    Month - 6   1534390   1573128   1751825   2292044
# 6    Month - 7   1820196   1992031   1786826   1688055
# 7    Month - 8   1625696   1665534   2161754   2363315
# 8    Month - 9   1652644   1873402   1755290   1422059
# 9   Month - 10   1852450   1913059   1754314   1608387
# 10  Month - 11   2004480   1740365   1317869   1970069
# 11  Month - 12   1537539   1875658   1237722   1460165
# 12  Month - 13   1254939   1588473   1348629   1733383
# 13  Month - 14   1821799   1844081   1617376   1872259
# 14  Month - 15   1128185   1804613   1767047   1234311
# 15  Month - 16   1491534   1542053   1882159   1590913
# ...

# %%
salesData.columns
# Out:
# Index(['Month', 'Zone - A', 'Zone - B', 'Zone - C', 'Zone - D'], dtype='object')

# %%
salesData.shape
# Out:
# (29, 5)

# %%
salesData.isna().sum() #checking for null values
# Out:
# Month       0
# Zone - A    0
# Zone - B    0
# Zone - C    0
# Zone - D    0
# dtype: int64

# %% [markdown]
# There is no null values in the dataset

# %%
salesData.info
# Out:
# <bound method DataFrame.info of          Month  Zone - A  Zone - B  Zone - C  Zone - D
# 0    Month - 1   1483525   1748451   1523308   2267260
# 1    Month - 2   1238428   1707421   2212113   1994341
# 2    Month - 3   1860771   2091194   1282374   1241600
# 3    Month - 4   1871571   1759617   2290580   2252681
# 4    Month - 5   1244922   1606010   1818334   1326062
# 5    Month - 6   1534390   1573128   1751825   2292044
# 6    Month - 7   1820196   1992031   1786826   1688055
# 7    Month - 8   1625696   1665534   2161754   2363315
# 8    Month - 9   1652644   1873402   1755290   1422059
# 9   Month - 10   1852450   1913059   1754314   1608387
# 10  Month - 11   2004480   1740365   1317869   1970069
# 11  Month - 12   1537539   1875658   1237722   1460165
# 12  Month - 13   1254939   1588473   1348629   1733383
# 13  Month - 14   1821799   1844081   1617376   1872259
# 14  Month - 15   1128185   1804613   1767047   1234311
# ...

# %% [markdown]
# ## 1. The mean sales generated by each zone.

# %%
salesData.describe()
# Out:
#            Zone - A      Zone - B      Zone - C      Zone - D
# count  2.900000e+01  2.900000e+01  2.900000e+01  2.900000e+01
# mean   1.540493e+06  1.755560e+06  1.772871e+06  1.842927e+06
# std    2.619401e+05  1.683899e+05  3.331937e+05  3.750165e+05
# min    1.128185e+06  1.527574e+06  1.237722e+06  1.234311e+06
# 25%    1.305972e+06  1.606010e+06  1.523308e+06  1.520406e+06
# 50%    1.534390e+06  1.740365e+06  1.767047e+06  1.854412e+06
# 75%    1.820196e+06  1.875658e+06  2.098463e+06  2.180416e+06
# max    2.004480e+06  2.091194e+06  2.290580e+06  2.364132e+06

# %%
salesData[['Zone - A', 'Zone - B', 'Zone - C', 'Zone - D']].mean() #finding the mean
# Out:
# Zone - A    1.540493e+06
# Zone - B    1.755560e+06
# Zone - C    1.772871e+06
# Zone - D    1.842927e+06
# dtype: float64

# %% [markdown]
# The mean sales of Zone-A =  1540493.1379310344
# The mean sales of Zone-B =  1755559.5862068965
# The mean sales of Zone-C =  1772871.0344827587
# The mean sales of Zone-D =  1842926.7586206896

# %% [markdown]
# ## 2.Total sales generated by all the zones for each month

# %%
salesData["Total sales"] = salesData.sum(axis=1) # sum is in the new column 'Total sales'.
salesData
# Out:
#          Month  Zone - A  Zone - B  Zone - C  Zone - D  Total sales
# 0    Month - 1   1483525   1748451   1523308   2267260      7022544
# 1    Month - 2   1238428   1707421   2212113   1994341      7152303
# 2    Month - 3   1860771   2091194   1282374   1241600      6475939
# 3    Month - 4   1871571   1759617   2290580   2252681      8174449
# 4    Month - 5   1244922   1606010   1818334   1326062      5995328
# 5    Month - 6   1534390   1573128   1751825   2292044      7151387
# 6    Month - 7   1820196   1992031   1786826   1688055      7287108
# 7    Month - 8   1625696   1665534   2161754   2363315      7816299
# 8    Month - 9   1652644   1873402   1755290   1422059      6703395
# 9   Month - 10   1852450   1913059   1754314   1608387      7128210
# 10  Month - 11   2004480   1740365   1317869   1970069      7032783
# 11  Month - 12   1537539   1875658   1237722   1460165      6111084
# 12  Month - 13   1254939   1588473   1348629   1733383      5925424
# ...

# %%
salesData[['Month','Total sales']]
# Out:
#          Month  Total sales
# 0    Month - 1      7022544
# 1    Month - 2      7152303
# 2    Month - 3      6475939
# 3    Month - 4      8174449
# 4    Month - 5      5995328
# 5    Month - 6      7151387
# 6    Month - 7      7287108
# 7    Month - 8      7816299
# 8    Month - 9      6703395
# 9   Month - 10      7128210
# 10  Month - 11      7032783
# 11  Month - 12      6111084
# 12  Month - 13      5925424
# 13  Month - 14      7155515
# 14  Month - 15      5934156
# 15  Month - 16      6506659
# 16  Month - 17      7149383
# 17  Month - 18      7083490
# 18  Month - 19      6971953
# 19  Month - 20      7124599
# 20  Month - 21      7389597
# 21  Month - 22      7560001
# 22  Month - 23      6687919
# 23  Month - 24      7784747
# 24  Month - 25      6095918
# 25  Month - 26      6512360
# 26  Month - 27      6267918
# 27  Month - 28      7470920
# 28  Month - 29      6772277

# %%
plt.figure(figsize=(19,10))
sns.barplot(data = salesData, x = 'Month', y = 'Total sales',color='purple')
plt.xlabel("Month", fontsize=12)
plt.ylabel("Total Monthly Sale", fontsize = 12)
plt.xticks(rotation = 45)
plt.show()

# %% [markdown]
# ## 3.Checking whether all the zones generate the same amount of sales.

# %% [markdown]
# H0 : All the zones generate the same amount of sales.
#
# H1 : There are difference in sales generated by each zone.

# %%
import scipy.stats as stats
f_value,p_value = stats.f_oneway(salesData['Zone - A'],salesData['Zone - B'],salesData['Zone - C'],salesData['Zone - D'])
print('f_value =',f_value)
print('p_value =',p_value)
# Out:
# f_value = 5.672056106843581
# p_value = 0.0011827601694503335

# %% [markdown]
# ###### Here the p-value is approximately zero and less than 0.05(p-value < 0.05), so we reject the null hypothesis and use the alternative hypothesis. That means the sales generated by each regions are different.
